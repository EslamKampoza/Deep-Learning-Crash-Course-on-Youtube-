# %% [markdown]
# <a href="https://colab.research.google.com/github/EslamKampoza/Deep-Learning-Crash-Course-on-Youtube-/blob/main/RandomForestTest_extrasensory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.tree import DecisionTreeClassifier

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
from drive.MyDrive.utilize.data import *
from drive.MyDrive.utilize.transform import *
from drive.MyDrive.utilize.feature_selection import *
from drive.MyDrive.utilize.test import *
# Out:
# Found 60 users data.

# %%
# Load all the data 
X, y, M, user_index, feature_names, label_names = load_all_data()

# %%
# Only select body state label
target_label = ['LYING_DOWN', 'SITTING', 'FIX_walking', 'FIX_running', 'BICYCLING', 'OR_standing']

# Use the last 5 user's data as test set
test_uuid = list(range(56, 61))

# Fill the Nan with mean value and normalize all the data 
pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('std_scaler', StandardScaler())
])

# %%
# Process the feature data and split the train test set

X_new, y_new, M_new = select_target_labels(X, y, M, target_label, label_names, drop_all_zero = False)
#y_new = np.sum(y_new * [1, 2, 3, 4, 5, 6], axis = 1)

X_new = pipeline.fit_transform(X_new, y_new)
X_train, y_train, M_train, X_test, y_test, M_test = split_by_users(X_new, y_new, M_new, test_uuid, user_index)

# %%
X.shape, y.shape, M.shape
X_new.shape, y_new.shape, M_new.shape
X_train.shape, X_test.shape
# Out:
# ((354481, 225), (22865, 225))

# %%
core_sensor = ['raw_acc', 'proc_gyro', 'watch_acceleration', 'audio_naive', 'location', 'discrete']
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((354481, 225), (354481, 6), (22865, 225), (22865, 6))

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((354481, 225), (354481, 6), (22865, 225), (22865, 6))

# %% [markdown]
# ## Random Forest Test

# %%
# from sklearn.ensemble import RandomForestClassifier
# model = RandomForestClassifier(class_weight = 'balanced', n_estimators = 10, min_samples_split = 10)

# model.fit(X_train, y_train)
# accuracy, sensitivity, specificity, BA = evaluate_model(model, X_test, y_test, report = True)

# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
# rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# rf = RandomForestRegressor(n_estimators = 10, min_samples_split = 10)
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(class_weight = 'balanced', n_estimators = 10, min_samples_split = 10)
# Train the model on training data
rf.fit(X_train, y_train);

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(X_test)
# # Calculate the absolute errors
# errors = abs(predictions - y_test)
# # Print out the mean absolute error (mae)
# print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')

# %%
for i in range(len(predictions)):
    for j in range(len(predictions[0])):
        if(predictions[i][j] == y_test[i][j]):
            print(target_label[j])
# Out:
# Streaming output truncated to the last 5000 lines.
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing
# LYING_DOWN
# SITTING
# FIX_walking
# FIX_running
# BICYCLING
# OR_standing

# %%
evaluate_model(rf, X_test, y_test, report = True)
# Out:
# accuaracy      sensitivity    specificity    BA
# 0.884408       0.268593       0.960154       0.614374
# (0.8844084845834245,
#  0.26859335137355667,
#  0.9601537773049587,
#  0.6143735643392577)

# %%
# Import tools needed for visualization
from sklearn.tree import export_graphviz
import pydot
# Pull out one tree from the forest
tree = rf.estimators_[5]
# Import tools needed for visualization
from sklearn.tree import export_graphviz
import pydot
# Pull out one tree from the forest
tree = rf.estimators_[5]
# Export the image to a dot file
export_graphviz(tree, out_file = 'tree.dot', feature_names = feature_names, rounded = True, precision = 1)
# Use dot file to create a graph
(graph, ) = pydot.graph_from_dot_file('tree.dot')
# Write graph to a png file
graph.write_png('tree.png')

# %%
# Use dot file to create a graph
(graph, ) = pydot.graph_from_dot_file('./tree.dot')
# Write graph to a png file
graph.write_png('tree.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pydot.py in create(self, prog, format, encoding)
#    1914                 arguments=arguments,
# -> 1915                 working_dir=tmp_dir,
#    1916             )
#
# /usr/local/lib/python3.7/site-packages/pydot.py in call_graphviz(program, arguments, working_dir, **kwargs)
#     135         stdout=subprocess.PIPE,
# --> 136         **kwargs
#     137     )
#
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1550                             err_msg += ': ' + repr(err_filename)
# -> 1551                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1552                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dot': 'dot'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-4d56a8bc9dfa> in <module>
#       2 (graph, ) = pydot.graph_from_dot_file('./tree.dot')
#       3 # Write graph to a png file
# ----> 4 graph.write_png('tree.png')
#
# /usr/local/lib/python3.7/site-packages/pydot.py in new_method(path, f, prog, encoding)
#    1732                 self.write(
#    1733                     path, format=f, prog=prog,
# -> 1734                     encoding=encoding)
#    1735             name = 'write_{fmt}'.format(fmt=frmt)
#    1736             self.__setattr__(name, new_method)
#
# /usr/local/lib/python3.7/site-packages/pydot.py in write(self, path, prog, format, encoding)
#    1815                 f.write(s)
#    1816         else:
# -> 1817             s = self.create(prog, format, encoding=encoding)
#    1818             with io.open(path, mode='wb') as f:
#    1819                 f.write(s)
#
# /usr/local/lib/python3.7/site-packages/pydot.py in create(self, prog, format, encoding)
#    1920                 args[1] = '"{prog}" not found in path.'.format(
#    1921                     prog=prog)
# -> 1922                 raise OSError(*args)
#    1923             else:
#    1924                 raise
#
# FileNotFoundError: [Errno 2] "dot" not found in path.

# %%
# Limit depth of tree to 3 levels
rf_small = RandomForestRegressor(n_estimators=10, max_depth = 3)
rf_small.fit(X_train, y_train)
# Extract the small tree
tree_small = rf_small.estimators_[5]
# Save the tree as a png image
export_graphviz(tree_small, out_file = 'small_tree.dot', feature_names = feature_names, rounded = True, precision = 1)
(graph, ) = pydot.graph_from_dot_file('small_tree.dot')
graph.write_png('small_tree.png');
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pydot.py in create(self, prog, format, encoding)
#    1914                 arguments=arguments,
# -> 1915                 working_dir=tmp_dir,
#    1916             )
#
# /usr/local/lib/python3.7/site-packages/pydot.py in call_graphviz(program, arguments, working_dir, **kwargs)
#     135         stdout=subprocess.PIPE,
# --> 136         **kwargs
#     137     )
#
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1550                             err_msg += ': ' + repr(err_filename)
# -> 1551                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1552                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dot': 'dot'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-73a92702cb14> in <module>
#       7 export_graphviz(tree_small, out_file = 'small_tree.dot', feature_names = feature_names, rounded = True, precision = 1)
#       8 (graph, ) = pydot.graph_from_dot_file('small_tree.dot')
# ----> 9 graph.write_png('small_tree.png');
#
# /usr/local/lib/python3.7/site-packages/pydot.py in new_method(path, f, prog, encoding)
#    1732                 self.write(
#    1733                     path, format=f, prog=prog,
# -> 1734                     encoding=encoding)
#    1735             name = 'write_{fmt}'.format(fmt=frmt)
#    1736             self.__setattr__(name, new_method)
#
# /usr/local/lib/python3.7/site-packages/pydot.py in write(self, path, prog, format, encoding)
#    1815                 f.write(s)
#    1816         else:
# -> 1817             s = self.create(prog, format, encoding=encoding)
#    1818             with io.open(path, mode='wb') as f:
#    1819                 f.write(s)
#
# /usr/local/lib/python3.7/site-packages/pydot.py in create(self, prog, format, encoding)
#    1920                 args[1] = '"{prog}" not found in path.'.format(
#    1921                     prog=prog)
# -> 1922                 raise OSError(*args)
#    1923             else:
#    1924                 raise
#
# FileNotFoundError: [Errno 2] "dot" not found in path.

# %%
(graph, ) = pydot.graph_from_dot_file('./small_tree.dot')
graph.write_png('small_tree.png');
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pydot.py in create(self, prog, format, encoding)
#    1914                 arguments=arguments,
# -> 1915                 working_dir=tmp_dir,
#    1916             )
#
# /usr/local/lib/python3.7/site-packages/pydot.py in call_graphviz(program, arguments, working_dir, **kwargs)
#     135         stdout=subprocess.PIPE,
# --> 136         **kwargs
#     137     )
#
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1550                             err_msg += ': ' + repr(err_filename)
# -> 1551                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1552                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dot': 'dot'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-ee21999c74a2> in <module>
#       1 (graph, ) = pydot.graph_from_dot_file('./small_tree.dot')
# ----> 2 graph.write_png('small_tree.png');
#
# /usr/local/lib/python3.7/site-packages/pydot.py in new_method(path, f, prog, encoding)
#    1732                 self.write(
#    1733                     path, format=f, prog=prog,
# -> 1734                     encoding=encoding)
#    1735             name = 'write_{fmt}'.format(fmt=frmt)
#    1736             self.__setattr__(name, new_method)
#
# /usr/local/lib/python3.7/site-packages/pydot.py in write(self, path, prog, format, encoding)
#    1815                 f.write(s)
#    1816         else:
# -> 1817             s = self.create(prog, format, encoding=encoding)
#    1818             with io.open(path, mode='wb') as f:
#    1819                 f.write(s)
#
# /usr/local/lib/python3.7/site-packages/pydot.py in create(self, prog, format, encoding)
#    1920                 args[1] = '"{prog}" not found in path.'.format(
#    1921                     prog=prog)
# -> 1922                 raise OSError(*args)
#    1923             else:
#    1924                 raise
#
# FileNotFoundError: [Errno 2] "dot" not found in path.

# %%
prediction_small = rf_small.predict(X_test)
prediction_small
# Out:
# array([[0.10534723, 0.52082522, 0.0411779 , 0.00221013, 0.00570575,
#         0.11883223],
#        [0.10534723, 0.52082522, 0.0411779 , 0.00221013, 0.00570575,
#         0.11883223],
#        [0.10534723, 0.52082522, 0.0411779 , 0.00221013, 0.00570575,
#         0.11883223],
#        ...,
#        [0.22083378, 0.25032794, 0.07841496, 0.00475426, 0.06191096,
#         0.17456144],
#        [0.22083378, 0.25032794, 0.07841496, 0.00475426, 0.06191096,
#         0.17456144],
#        [0.22083378, 0.25032794, 0.07841496, 0.00475426, 0.06191096,
#         0.17456144]])

# %%
y_test.shape
# Out:
# (17957, 6)

# %%
y_pred = [[False]*6]*17957
for i in range(len(prediction_small)):
    y_pred_temp = [False]*6
    for j in range(len(prediction_small[0])):
        if (prediction_small[i][j] > 0.5):
            y_pred_temp[j] = True
        else:
            y_pred_temp[j] = False
    y_pred[i] = y_pred_temp

# %%
y_pred == y_test
# Out:
# array([[ True, False,  True,  True,  True,  True],
#        [ True, False,  True,  True,  True,  True],
#        [ True, False,  True,  True,  True,  True],
#        ...,
#        [ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True]])

# %%
np.sum(y_pred == y_test), len(y_test)*len(y_test[0])
# Out:
# (100084, 107742)

# %%
np.sum(y_pred == y_test)/(len(y_test)*len(y_test[0]))
# Out:
# 0.9289227970522174
